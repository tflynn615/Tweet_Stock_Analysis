# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import pandas as pd
import datetime
import yfinance
import mplfinance as mpf
import matplotlib.dates as mpl_dates 
import matplotlib.pyplot as plt 

# google colab specific code
#from google.colab import drive 
#drive.mount('/content/drive')

# %%
#pip install yfinance

# %%
#pip install mplfinance

# %% [markdown]
# ## Load data

# %%
tweet_id = pd.read_csv('Company_Tweet.csv')

# %%
tweet_id.head()
# Out:
#              tweet_id ticker_symbol
# 0  550803612197457920          AAPL
# 1  550803610825928706          AAPL
# 2  550803225113157632          AAPL
# 3  550802957370159104          AAPL
# 4  550802855129382912          AAPL

# %%
comp_name = pd.read_csv("Company.csv")
#comp_name.head()

# %%
tweet_df = pd.read_csv('Tweet.csv')
tweet_df.head()
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         0
# 2            0         0
# 3            0         1
# 4            0         1

# %%
name = 'aapl'
ticker = yfinance.Ticker(name)
df_aapl = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')

df_aapl.head()
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2015-01-02  25.286885  25.298236  24.369756  24.819241  212818400        0.0
# 2015-01-05  24.583150  24.664874  23.929355  24.120045  257142000        0.0
# 2015-01-06  24.185883  24.387924  23.752289  24.122320  263188400        0.0
# 2015-01-07  24.335706  24.562718  24.222200  24.460564  160423600        0.0
# 2015-01-08  24.796547  25.459422  24.676229  25.400398  237458000        0.0
#
#             Stock Splits
# Date
# 2015-01-02             0
# 2015-01-05             0
# 2015-01-06             0
# 2015-01-07             0
# 2015-01-08             0

# %%
name = 'amzn'
ticker = yfinance.Ticker(name)
df_amzn = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_amzn.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-01-02  312.579987  314.750000  306.959991  308.519989  2783200
# 2015-01-05  307.010010  308.380005  300.850006  302.190002  2774200
# 2015-01-06  302.239990  303.000000  292.380005  295.290009  3519000
# 2015-01-07  297.500000  301.279999  295.329987  298.420013  2640300
# 2015-01-08  300.320007  303.140015  296.109985  300.459991  3088400
#
#             Dividends  Stock Splits
# Date
# 2015-01-02          0             0
# 2015-01-05          0             0
# 2015-01-06          0             0
# 2015-01-07          0             0
# 2015-01-08          0             0

# %%
name = 'goog'
ticker = yfinance.Ticker(name)
df_goog = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_goog.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-01-02  527.561584  529.815369  522.665039  523.373108  1447563
# 2015-01-05  521.827332  522.894409  511.655243  512.463013  2059840
# 2015-01-06  513.589966  514.761719  499.678131  500.585632  2899940
# 2015-01-07  505.611847  505.855164  498.281952  499.727997  2065054
# 2015-01-08  496.626526  502.101471  489.655640  501.303680  3353582
#
#             Dividends  Stock Splits
# Date
# 2015-01-02          0           0.0
# 2015-01-05          0           0.0
# 2015-01-06          0           0.0
# 2015-01-07          0           0.0
# 2015-01-08          0           0.0

# %%
name = 'msft'
ticker = yfinance.Ticker(name)
df_msft = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_msft.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2015-01-02  41.259780  41.931820  41.153670  41.348206  27913900        0.0
# 2015-01-05  41.003344  41.321679  40.897233  40.967976  39673900        0.0
# 2015-01-06  41.012201  41.339378  40.269418  40.366688  36447900        0.0
# 2015-01-07  40.658473  41.082920  40.225186  40.879539  29114100        0.0
# 2015-01-08  41.339360  42.223624  41.312833  42.082142  29645200        0.0
#
#             Stock Splits
# Date
# 2015-01-02             0
# 2015-01-05             0
# 2015-01-06             0
# 2015-01-07             0
# 2015-01-08             0

# %%
name = 'tsla'
ticker = yfinance.Ticker(name)
df_tsla = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_tsla.tail()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-12-23  82.356003  84.402000  82.000000  83.844002  66598000          0
# 2019-12-24  83.671997  85.094002  82.538002  85.050003  40273500          0
# 2019-12-26  85.582001  86.695999  85.269997  86.188004  53169500          0
# 2019-12-27  87.000000  87.061996  85.222000  86.075996  49728500          0
# 2019-12-30  85.758003  85.800003  81.851997  82.940002  62932000          0
#
#             Stock Splits
# Date
# 2019-12-23             0
# 2019-12-24             0
# 2019-12-26             0
# 2019-12-27             0
# 2019-12-30             0

# %%
df_tsla.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends         int64
# Stock Splits      int64
# dtype: object

# %%
df_tsla
#df_tsla['Date'] = df_tsla['Date'].apply(mpl_dates.date2num)

#df_tsla = df_tsla.loc[:,['Date', 'Open', 'Close', 'High', 'Low', 'Volume']]
#df_tsla
#mpf.plot(df_tsla, type='candle', mav=(21,50), figsize=(10,6), style='mike', volume=True)
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2015-01-02  44.574001  44.650002  42.652000  43.862000  23822000          0
# 2015-01-05  42.910000  43.299999  41.431999  42.018002  26842500          0
# 2015-01-06  42.012001  42.840000  40.841999  42.256001  31309500          0
# 2015-01-07  42.669998  42.956001  41.956001  42.189999  14842000          0
# 2015-01-08  42.562000  42.759998  42.001999  42.124001  17212500          0
# ...               ...        ...        ...        ...       ...        ...
# 2019-12-23  82.356003  84.402000  82.000000  83.844002  66598000          0
# 2019-12-24  83.671997  85.094002  82.538002  85.050003  40273500          0
# 2019-12-26  85.582001  86.695999  85.269997  86.188004  53169500          0
# 2019-12-27  87.000000  87.061996  85.222000  86.075996  49728500          0
# 2019-12-30  85.758003  85.800003  81.851997  82.940002  62932000          0
#
#             Stock Splits
# Date
# ...

# %% [markdown]
# ## Transformation

# %%
#merging company tweet, and tweet dfs on "tweet_id"
merged_df = pd.merge(tweet_id, tweet_df, on="tweet_id")
merged_df.head()
# Out:
#              tweet_id ticker_symbol      writer   post_date  \
# 0  550803612197457920          AAPL  SentiQuant  1420156789
# 1  550803612197457920          AMZN  SentiQuant  1420156789
# 2  550803610825928706          AAPL  SentiQuant  1420156788
# 3  550803610825928706         GOOGL  SentiQuant  1420156788
# 4  550803610825928706          AMZN  SentiQuant  1420156788
#
#                                                 body  comment_num  \
# 0  #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 1  #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 2  #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
# 3  #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
# 4  #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         1
# 2            0         1
# 3            0         1
# 4            0         1

# %%
merged_df.ticker_symbol.unique()
# Out:
# array(['AAPL', 'AMZN', 'GOOGL', 'TSLA', 'GOOG', 'MSFT'], dtype=object)

# %%
# Since we have 2 google, removing all the googl ticker 
merged_df = merged_df[merged_df.ticker_symbol !="GOOGL"]

# %%
merged_df.ticker_symbol.unique()
# Out:
# array(['AAPL', 'AMZN', 'TSLA', 'GOOG', 'MSFT'], dtype=object)

# %%
#converting unix epoch to date format similar
merged_df["post_date"] = pd.to_datetime(merged_df["post_date"], unit='s').dt.strftime('%Y-%m-%d')
merged_df.sample(20)
# Out:
#                     tweet_id ticker_symbol           writer   post_date  \
# 1333095   992463593940676609          TSLA    PortfolioBuzz  2018-05-04
# 1931760   627760318500831233          GOOG       IHNewsDesk  2015-08-02
# 3494567   722197992711716865          TSLA    CantechLetter  2016-04-18
# 152794    588757542580461568          AAPL           noneck  2015-04-16
# 4277613  1187745789138886665          TSLA     investatrade  2019-10-25
# 4299705  1197737883546849280          TSLA      nikbonaddio  2019-11-22
# 3934150  1051855849310887936          TSLA          unemon1  2018-10-15
# 674282    742554890002518017          AAPL     _peripherals  2016-06-14
# 1034532   861986727602335746          AAPL           TCMLLC  2017-05-09
# 2828885   890663898155712513          AMZN   DayTradeCanada  2017-07-27
# 435626    678826369501945856          AAPL         IHPosts2  2015-12-21
# 2083506   798757738574532608          GOOG    It_c0nsulting  2016-11-16
# ...

# %%
#checking values before dropping null values
merged_df.count()
# Out:
# tweet_id         4008876
# ticker_symbol    4008876
# writer           3955885
# post_date        4008876
# body             4008876
# comment_num      4008876
# retweet_num      4008876
# like_num         4008876
# dtype: int64

# %%
#dropping null values
merged_df = merged_df.dropna()

# %%
#checking values/count after dropping null values
merged_df.count()
# Out:
# tweet_id         3955885
# ticker_symbol    3955885
# writer           3955885
# post_date        3955885
# body             3955885
# comment_num      3955885
# retweet_num      3955885
# like_num         3955885
# dtype: int64

# %%
# Checking start and end date of the tweet data 
merged_df = merged_df.sort_values(by='post_date')
merged_df.head()
# Out:
#                    tweet_id ticker_symbol        writer   post_date  \
# 0        550803612197457920          AAPL    SentiQuant  2015-01-01
# 3378099  550658779117666304          TSLA    kirillklip  2015-01-01
# 3378098  550631850981748737          TSLA  Stockaholics  2015-01-01
# 3378097  550610051753603074          TSLA    caroltheva  2015-01-01
# 3378096  550602053580775424          TSLA    caroltheva  2015-01-01
#
#                                                       body  comment_num  \
# 0        #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 3378099  Almost 10,000 Electric Cars Were Sold In China...            0
# 3378098  Our Penny Stock Picks Gained Over 968% In the ...            0
# 3378097  Why technical analysis won\'t work all the tim...            0
# 3378096  Free course on margin usage in Options http://...            0
#
#          retweet_num  like_num
# 0                  0         1
# 3378099            1         1
# ...

# %%
merged_df.tail()
# Out:
#                     tweet_id ticker_symbol          writer   post_date  \
# 1863512  1212051687709511681          AAPL    OppayahTwitR  2019-12-31
# 1863511  1212051548521586689          AAPL  TheOptionsPros  2019-12-31
# 1863510  1212051421446725633          AAPL  Prometheus_Cap  2019-12-31
# 1863521  1212054020749234181          AMZN     jonny_red32  2019-12-31
# 4336444  1212160015332728833          TSLA     Commuternyc  2019-12-31
#
#                                                       body  comment_num  \
# 1863512  Never underestimate the power of well funded 8...            1
# 1863511  $AAPL #AAPL not giving up on trying to get ove...            0
# 1863510  $AAPL will Outperform $QQQ in the next decade ...            0
# 1863521  Is Spotify Stock A Buy Right Now? Here's What ...            0
# 4336444  Patiently Waiting for the no twitter sitter tw...            0
#
#          retweet_num  like_num
# 1863512            0         0
# 1863511            0         0
# ...

# %%
# Double check nulls
merged_df.isnull().sum()
# Out:
# tweet_id         0
# ticker_symbol    0
# writer           0
# post_date        0
# body             0
# comment_num      0
# retweet_num      0
# like_num         0
# dtype: int64

# %%
# remane post_date 
merged_df = merged_df.rename(columns={'post_date': 'Date'}, errors='raise')
merged_df.head()
# Out:
#                    tweet_id ticker_symbol        writer        Date  \
# 0        550803612197457920          AAPL    SentiQuant  2015-01-01
# 3378099  550658779117666304          TSLA    kirillklip  2015-01-01
# 3378098  550631850981748737          TSLA  Stockaholics  2015-01-01
# 3378097  550610051753603074          TSLA    caroltheva  2015-01-01
# 3378096  550602053580775424          TSLA    caroltheva  2015-01-01
#
#                                                       body  comment_num  \
# 0        #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 3378099  Almost 10,000 Electric Cars Were Sold In China...            0
# 3378098  Our Penny Stock Picks Gained Over 968% In the ...            0
# 3378097  Why technical analysis won\'t work all the tim...            0
# 3378096  Free course on margin usage in Options http://...            0
#
#          retweet_num  like_num
# 0                  0         1
# 3378099            1         1
# ...

# %%
###keeping write and body for vizs######



#merged_df = merged_df.drop(columns=['writer', 'body'])
#merged_df.head()

# %%
###reading to csv for viz
merged_df.to_csv("merged_tweet.csv",index=False)

# %% [markdown]
# # tweet activity df for each tickers

# %% [markdown]
# # Apple

# %%
# columns
cols = ["Date","tweet_count"]

# %%
AAPL = merged_df[(merged_df['ticker_symbol']=="AAPL")]
AAPL
# Out:
#                     tweet_id ticker_symbol           writer        Date  \
# 0         550803612197457920          AAPL       SentiQuant  2015-01-01
# 370       550447574285418497          AAPL        btcgemini  2015-01-01
# 371       550445850170642432          AAPL   JorelLaraKalel  2015-01-01
# 372       550445066444369921          AAPL       Bidnessetc  2015-01-01
# 373       550444970738335744          AAPL     espositooooo  2015-01-01
# ...                      ...           ...              ...         ...
# 1863515  1212052746947440640          AAPL     ChoZynTradeZ  2019-12-31
# 1863514  1212051918228533249          AAPL  KingGordonGekko  2019-12-31
# 1863512  1212051687709511681          AAPL     OppayahTwitR  2019-12-31
# 1863511  1212051548521586689          AAPL   TheOptionsPros  2019-12-31
# 1863510  1212051421446725633          AAPL   Prometheus_Cap  2019-12-31
#
#                                                       body  comment_num  \
# ...

# %%
#creading df of tweets per day to merge with stock dfs
aapl_df = pd.DataFrame(AAPL.Date.value_counts()).reset_index()
#setting the appropriate columns
aapl_df.columns=cols

aapl_df
# Out:
#             Date  tweet_count
# 0     2016-09-07         5018
# 1     2019-01-03         4914
# 2     2015-03-09         4615
# 3     2016-09-09         4509
# 4     2015-04-27         4453
# ...          ...          ...
# 1814  2017-03-28           27
# 1815  2018-10-03           14
# 1816  2017-03-13           12
# 1817  2015-05-02           10
# 1818  2017-09-08            7
#
# [1819 rows x 2 columns]

# %% [markdown]
# # Amazon

# %%
AMZN = merged_df[(merged_df["ticker_symbol"]=="AMZN")]

amzn_df = pd.DataFrame(AMZN.Date.value_counts()).reset_index()
amzn_df.columns=cols

amzn_df
# Out:
#             Date  tweet_count
# 0     2017-06-16         4167
# 1     2015-07-23         2385
# 2     2016-01-28         2231
# 3     2015-07-24         2197
# 4     2018-07-26         2159
# ...          ...          ...
# 1821  2018-09-21           20
# 1822  2015-03-28           16
# 1823  2017-10-18           12
# 1824  2017-05-30           11
# 1825  2015-05-03           10
#
# [1826 rows x 2 columns]

# %% [markdown]
# # Google

# %%
GOOG = merged_df[(merged_df["ticker_symbol"]=="GOOG")]

goog_df = pd.DataFrame(GOOG.Date.value_counts()).reset_index()
goog_df.columns=cols

goog_df
# Out:
#             Date  tweet_count
# 0     2016-10-05         1518
# 1     2016-05-19         1477
# 2     2016-10-04         1446
# 3     2015-07-17         1220
# 4     2016-05-18         1050
# ...          ...          ...
# 1820  2019-11-30           23
# 1821  2019-01-12           22
# 1822  2016-01-08           22
# 1823  2016-08-18           14
# 1824  2019-05-26            9
#
# [1825 rows x 2 columns]

# %% [markdown]
# # Microsoft

# %%
MSFT = merged_df[(merged_df["ticker_symbol"]=="MSFT")]

msft_df = pd.DataFrame(MSFT.Date.value_counts()).reset_index()
msft_df.columns=cols

msft_df
# Out:
#             Date  tweet_count
# 0     2016-06-13         2884
# 1     2016-06-14         1755
# 2     2015-01-27         1168
# 3     2016-04-22         1002
# 4     2016-10-20          964
# ...          ...          ...
# 1821  2015-08-29           27
# 1822  2016-04-02           25
# 1823  2015-05-02           25
# 1824  2015-05-03           11
# 1825  2019-06-18            9
#
# [1826 rows x 2 columns]

# %% [markdown]
# # Tesla

# %%
TSLA = merged_df[(merged_df["ticker_symbol"]=="TSLA")]

tsla_df = pd.DataFrame(TSLA.Date.value_counts()).reset_index()
tsla_df.columns=cols

tsla_df.dtypes
# Out:
# Date           object
# tweet_count     int64
# dtype: object

# %% [markdown]
# # merging tweet activity to original

# %%
ap_merged = pd.merge(AAPL, aapl_df, on='Date')
ap_merged
# Out:
#                     tweet_id ticker_symbol           writer        Date  \
# 0         550803612197457920          AAPL       SentiQuant  2015-01-01
# 1         550447574285418497          AAPL        btcgemini  2015-01-01
# 2         550445850170642432          AAPL   JorelLaraKalel  2015-01-01
# 3         550445066444369921          AAPL       Bidnessetc  2015-01-01
# 4         550444970738335744          AAPL     espositooooo  2015-01-01
# ...                      ...           ...              ...         ...
# 1414797  1212052746947440640          AAPL     ChoZynTradeZ  2019-12-31
# 1414798  1212051918228533249          AAPL  KingGordonGekko  2019-12-31
# 1414799  1212051687709511681          AAPL     OppayahTwitR  2019-12-31
# 1414800  1212051548521586689          AAPL   TheOptionsPros  2019-12-31
# 1414801  1212051421446725633          AAPL   Prometheus_Cap  2019-12-31
#
#                                                       body  comment_num  \
# ...

# %%
amzn_merged = pd.merge(AMZN, amzn_df, on='Date')
amzn_merged
# Out:
#                    tweet_id ticker_symbol           writer        Date  \
# 0        550447850857828352          AMZN   JorelLaraKalel  2015-01-01
# 1        550455384734183424          AMZN  StocksThatDoubl  2015-01-01
# 2        550460180631011328          AMZN  Maximum_Pain_cm  2015-01-01
# 3        550458700402413569          AMZN      BoogieColin  2015-01-01
# 4        550458273850470401          AMZN            OUDMG  2015-01-01
# ...                     ...           ...              ...         ...
# 709187  1212047114873819139          AMZN      davidmoadel  2019-12-31
# 709188  1212051164235255808          AMZN     Stockpro1221  2019-12-31
# 709189  1212052746947440640          AMZN     ChoZynTradeZ  2019-12-31
# 709190  1212051687709511681          AMZN     OppayahTwitR  2019-12-31
# 709191  1212054020749234181          AMZN      jonny_red32  2019-12-31
#
#                                                      body  comment_num  \
# ...

# %%
goog_merged = pd.merge(GOOG, goog_df, on='Date')
goog_merged
# Out:
#                    tweet_id ticker_symbol           writer        Date  \
# 0        550447850857828352          GOOG   JorelLaraKalel  2015-01-01
# 1        550453087731982336          GOOG         DCaptura  2015-01-01
# 2        550461555423584257          GOOG       t_nathan95  2015-01-01
# 3        550794780297285633          GOOG  InvestorHangout  2015-01-01
# 4        550793131684151296          GOOG     rosnerstocks  2015-01-01
# ...                     ...           ...              ...         ...
# 384886  1212067050409070595          GOOG         ZACKZAMU  2019-12-31
# 384887  1212089690104291328          GOOG      davidmoadel  2019-12-31
# 384888  1212059157416808448          GOOG          StckPro  2019-12-31
# 384889  1212049629371604993          GOOG  stickycactusink  2019-12-31
# 384890  1212055478857093121          GOOG    PortfolioBuzz  2019-12-31
#
#                                                      body  comment_num  \
# ...

# %%
msft_merged = pd.merge(MSFT, msft_df, on='Date')
msft_merged
# Out:
#                    tweet_id ticker_symbol           writer        Date  \
# 0        550687106746818560          MSFT         SSaints1  2015-01-01
# 1        550678413846261761          MSFT       caroltheva  2015-01-01
# 2        550674530432454656          MSFT     WeinsteinTST  2015-01-01
# 3        550673862304595968          MSFT  laurenholmesNYC  2015-01-01
# 4        550670428830990336          MSFT      stockwire24  2015-01-01
# ...                     ...           ...              ...         ...
# 373793  1212060837999005697          MSFT          Options  2019-12-31
# 373794  1212050451115499521          MSFT   Drugdoctor2014  2019-12-31
# 373795  1212049629371604993          MSFT  stickycactusink  2019-12-31
# 373796  1212055478857093121          MSFT    PortfolioBuzz  2019-12-31
# 373797  1212054809823653890          MSFT    realsheepwolf  2019-12-31
#
#                                                      body  comment_num  \
# ...

# %%
tsla_merged = pd.merge(TSLA, tsla_df, on='Date')
tsla_merged
# Out:
#                     tweet_id ticker_symbol           writer        Date  \
# 0         550658779117666304          TSLA       kirillklip  2015-01-01
# 1         550631850981748737          TSLA     Stockaholics  2015-01-01
# 2         550610051753603074          TSLA       caroltheva  2015-01-01
# 3         550602053580775424          TSLA       caroltheva  2015-01-01
# 4         550589782150381568          TSLA    aaplstocknews  2015-01-01
# ...                      ...           ...              ...         ...
# 1073197  1212050451115499521          TSLA   Drugdoctor2014  2019-12-31
# 1073198  1212049629371604993          TSLA  stickycactusink  2019-12-31
# 1073199  1212049349737373696          TSLA      davidmoadel  2019-12-31
# 1073200  1212051164235255808          TSLA     Stockpro1221  2019-12-31
# 1073201  1212160015332728833          TSLA      Commuternyc  2019-12-31
#
#                                                       body  comment_num  \
# ...

# %% [markdown]
# ## final merge- adding percent change and ticker for viz

# %% [markdown]
# # Apple

# %%
df_aapl_f = df_aapl
df_aapl_f
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2015-01-02  25.286885  25.298236  24.369756  24.819241  212818400        0.0
# 2015-01-05  24.583150  24.664874  23.929355  24.120045  257142000        0.0
# 2015-01-06  24.185883  24.387924  23.752289  24.122320  263188400        0.0
# 2015-01-07  24.335706  24.562718  24.222200  24.460564  160423600        0.0
# 2015-01-08  24.796547  25.459422  24.676229  25.400398  237458000        0.0
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-23  69.310552  70.229652  69.271019  70.167885   98572000        0.0
# 2019-12-24  70.338354  70.387771  69.901043  70.234581   48478800        0.0
# 2019-12-26  70.370482  71.645364  70.340834  71.628067   93121200        0.0
# 2019-12-27  71.927010  72.631161  71.185800  71.600876  146266000        0.0
# 2019-12-30  71.516870  72.314908  70.469295  72.025833  144114400        0.0
#
#             Stock Splits
# Date
# ...

# %%
#df_aapl_f['Date'] = pd.to_datetime(df_aapl_f.index)
#df_aapl_f["Date"] = pd.to_datetime(df_aapl_f["Date"], unit='s').dt.strftime('%Y-%m-%d')

df_aapl_f = df_aapl_f.reset_index()
df_aapl_f["Date"] = pd.to_datetime(df_aapl_f["Date"], unit='s').dt.strftime('%Y-%m-%d')
df_aapl_f
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 0     2015-01-02  25.286885  25.298236  24.369756  24.819241  212818400
# 1     2015-01-05  24.583150  24.664874  23.929355  24.120045  257142000
# 2     2015-01-06  24.185883  24.387924  23.752289  24.122320  263188400
# 3     2015-01-07  24.335706  24.562718  24.222200  24.460564  160423600
# 4     2015-01-08  24.796547  25.459422  24.676229  25.400398  237458000
# ...          ...        ...        ...        ...        ...        ...
# 1252  2019-12-23  69.310552  70.229652  69.271019  70.167885   98572000
# 1253  2019-12-24  70.338354  70.387771  69.901043  70.234581   48478800
# 1254  2019-12-26  70.370482  71.645364  70.340834  71.628067   93121200
# 1255  2019-12-27  71.927010  72.631161  71.185800  71.600876  146266000
# 1256  2019-12-30  71.516870  72.314908  70.469295  72.025833  144114400
#
#       Dividends  Stock Splits
# 0           0.0             0
# 1           0.0             0
# ...

# %%
df_aapl_f.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits      int64
# dtype: object

# %%
final_apple = pd.merge(df_aapl_f, aapl_df, on='Date')
final_apple
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 0     2015-01-02  25.286885  25.298236  24.369756  24.819241  212818400
# 1     2015-01-05  24.583150  24.664874  23.929355  24.120045  257142000
# 2     2015-01-06  24.185883  24.387924  23.752289  24.122320  263188400
# 3     2015-01-07  24.335706  24.562718  24.222200  24.460564  160423600
# 4     2015-01-08  24.796547  25.459422  24.676229  25.400398  237458000
# ...          ...        ...        ...        ...        ...        ...
# 1249  2019-12-23  69.310552  70.229652  69.271019  70.167885   98572000
# 1250  2019-12-24  70.338354  70.387771  69.901043  70.234581   48478800
# 1251  2019-12-26  70.370482  71.645364  70.340834  71.628067   93121200
# 1252  2019-12-27  71.927010  72.631161  71.185800  71.600876  146266000
# 1253  2019-12-30  71.516870  72.314908  70.469295  72.025833  144114400
#
#       Dividends  Stock Splits  tweet_count
# 0           0.0             0          864
# ...

# %%
final_apple['price_action'] = final_apple['Close'] - final_apple['Open']

final_apple.tail()
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 1249  2019-12-23  69.310552  70.229652  69.271019  70.167885   98572000
# 1250  2019-12-24  70.338354  70.387771  69.901043  70.234581   48478800
# 1251  2019-12-26  70.370482  71.645364  70.340834  71.628067   93121200
# 1252  2019-12-27  71.927010  72.631161  71.185800  71.600876  146266000
# 1253  2019-12-30  71.516870  72.314908  70.469295  72.025833  144114400
#
#       Dividends  Stock Splits  tweet_count  price_action
# 1249        0.0             0          595      0.857333
# 1250        0.0             0          349     -0.103773
# 1251        0.0             0          686      1.257585
# 1252        0.0             0          380     -0.326134
# 1253        0.0             0          724      0.508964

# %%
final_apple = final_apple.drop(columns=['Dividends','Stock Splits'])
final_apple
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 0     2015-01-02  25.286885  25.298236  24.369756  24.819241  212818400
# 1     2015-01-05  24.583150  24.664874  23.929355  24.120045  257142000
# 2     2015-01-06  24.185883  24.387924  23.752289  24.122320  263188400
# 3     2015-01-07  24.335706  24.562718  24.222200  24.460564  160423600
# 4     2015-01-08  24.796547  25.459422  24.676229  25.400398  237458000
# ...          ...        ...        ...        ...        ...        ...
# 1249  2019-12-23  69.310552  70.229652  69.271019  70.167885   98572000
# 1250  2019-12-24  70.338354  70.387771  69.901043  70.234581   48478800
# 1251  2019-12-26  70.370482  71.645364  70.340834  71.628067   93121200
# 1252  2019-12-27  71.927010  72.631161  71.185800  71.600876  146266000
# 1253  2019-12-30  71.516870  72.314908  70.469295  72.025833  144114400
#
#       tweet_count  price_action
# 0             864     -0.467645
# 1            1145     -0.463105
# ...

# %%
final_apple["Ticker"] = "AAPL"
final_apple['Percent_Change'] = ((final_apple["Close"]-final_apple["Open"])/final_apple["Open"])*100
final_apple
# Out:
#             Date       Open       High        Low      Close     Volume  \
# 0     2015-01-02  25.286885  25.298236  24.369756  24.819241  212818400
# 1     2015-01-05  24.583150  24.664874  23.929355  24.120045  257142000
# 2     2015-01-06  24.185883  24.387924  23.752289  24.122320  263188400
# 3     2015-01-07  24.335706  24.562718  24.222200  24.460564  160423600
# 4     2015-01-08  24.796547  25.459422  24.676229  25.400398  237458000
# ...          ...        ...        ...        ...        ...        ...
# 1249  2019-12-23  69.310552  70.229652  69.271019  70.167885   98572000
# 1250  2019-12-24  70.338354  70.387771  69.901043  70.234581   48478800
# 1251  2019-12-26  70.370482  71.645364  70.340834  71.628067   93121200
# 1252  2019-12-27  71.927010  72.631161  71.185800  71.600876  146266000
# 1253  2019-12-30  71.516870  72.314908  70.469295  72.025833  144114400
#
#       tweet_count  price_action Ticker  Percent_Change
# ...

# %%
x_labels =["AAPL"]
fig, ax = plt.subplots()
ax.boxplot(final_apple["Percent_Change"], labels=x_labels)
ax.set_title('Distribution of Daily Percent Change in Price')
ax.grid()
plt.show()

# %%
final_apple.to_csv('final_aapl.csv', index=False)

# %%
x_axis = final_apple['Date']
y_axis = final_apple['tweet_count']
plt.plot(x_axis, y_axis, label='Apple')
plt.title("Apple tweet volume")
plt.legend()
#plt.rcParams["figure.figsize"] = (10,4)

# plt.savefig("add a path and figure extension")

# %%
x_axis = final_apple['Date']
y_axis = final_apple['price_action']
plt.plot(x_axis, y_axis, label='Apple')
plt.title("Apple Price action")
plt.legend()

# %% [markdown]
# # Amazon

# %%
df_amzn_f = df_amzn

df_amzn_f = df_amzn_f.reset_index()

df_amzn_f["Date"] = pd.to_datetime(df_amzn_f["Date"], unit='s').dt.strftime('%Y-%m-%d')


final_amzn = pd.merge(df_amzn_f, amzn_df, on='Date')

final_amzn['price_action'] = final_amzn['Close'] - final_amzn['Open']
final_amzn["Ticker"] = "AMZN"
final_amzn['Percent_Change'] = ((final_amzn["Close"]-final_amzn["Open"])/final_amzn["Open"])*100

final_amzn = final_amzn.drop(columns=['Dividends','Stock Splits'])

# %%
final_amzn
# Out:
#             Date         Open         High          Low        Close   Volume  \
# 0     2015-01-02   312.579987   314.750000   306.959991   308.519989  2783200
# 1     2015-01-05   307.010010   308.380005   300.850006   302.190002  2774200
# 2     2015-01-06   302.239990   303.000000   292.380005   295.290009  3519000
# 3     2015-01-07   297.500000   301.279999   295.329987   298.420013  2640300
# 4     2015-01-08   300.320007   303.140015   296.109985   300.459991  3088400
# ...          ...          ...          ...          ...          ...      ...
# 1252  2019-12-23  1788.260010  1793.000000  1784.510010  1793.000000  2136400
# 1253  2019-12-24  1793.810059  1795.569946  1787.579956  1789.209961   881300
# 1254  2019-12-26  1801.010010  1870.459961  1799.500000  1868.770020  6005400
# 1255  2019-12-27  1882.920044  1901.400024  1866.010010  1869.800049  6186600
# 1256  2019-12-30  1874.000000  1884.000000  1840.619995  1846.890015  3674700
#
# ...

# %%
x_labels =["AMZN"]
fig, ax = plt.subplots()
ax.boxplot(final_amzn["Percent_Change"], labels=x_labels)
ax.set_title('Distribution of Daily Percent Change in Price')
ax.grid()
plt.show()

# %%
final_amzn.to_csv('final_amzn.csv', index=False)

# %% [markdown]
# # google

# %%
df_goog_f = df_goog

df_goog_f = df_goog_f.reset_index()

df_goog_f["Date"] = pd.to_datetime(df_goog_f["Date"], unit='s').dt.strftime('%Y-%m-%d')


final_goog = pd.merge(df_goog_f, goog_df, on='Date')

final_goog['price_action'] = final_goog['Close'] - final_goog['Open']
final_goog["Ticker"] = "GOOG"
final_goog['Percent_Change'] = ((final_goog["Close"]-final_goog["Open"])/final_goog["Open"])*100

final_goog = final_goog.drop(columns=['Dividends','Stock Splits'])

final_goog
# Out:
#             Date         Open         High          Low        Close   Volume  \
# 0     2015-01-02   527.561584   529.815369   522.665039   523.373108  1447563
# 1     2015-01-05   521.827332   522.894409   511.655243   512.463013  2059840
# 2     2015-01-06   513.589966   514.761719   499.678131   500.585632  2899940
# 3     2015-01-07   505.611847   505.855164   498.281952   499.727997  2065054
# 4     2015-01-08   496.626526   502.101471   489.655640   501.303680  3353582
# ...          ...          ...          ...          ...          ...      ...
# 1251  2019-12-23  1355.869995  1359.800049  1346.510010  1348.839966   883100
# 1252  2019-12-24  1348.500000  1350.260010  1342.780029  1343.560059   347500
# 1253  2019-12-26  1346.170044  1361.327026  1344.469971  1360.400024   667500
# 1254  2019-12-27  1362.989990  1364.530029  1349.310059  1351.890015  1038400
# 1255  2019-12-30  1350.000000  1353.000000  1334.020020  1336.140015  1050900
#
# ...

# %%
x_labels =["GOOG"]
fig, ax = plt.subplots()
ax.boxplot(final_goog["Percent_Change"], labels=x_labels)
ax.set_title('Distribution of Daily Percent Change in Price')
ax.grid()
plt.show()

# %%
final_goog.to_csv('final_goog.csv', index=False)

# %% [markdown]
# # microsoft

# %%
df_msft_f = df_msft


df_msft_f = df_msft_f.reset_index()

df_msft_f["Date"] = pd.to_datetime(df_msft_f["Date"], unit='s').dt.strftime('%Y-%m-%d')

final_msft = pd.merge(df_msft_f, msft_df, on='Date')

final_msft['price_action'] = final_msft['Close'] - final_msft['Open']
final_msft["Ticker"] = "MSFT"
final_msft['Percent_Change'] = ((final_msft["Close"]-final_msft["Open"])/final_msft["Open"])*100

final_msft = final_msft.drop(columns=['Dividends','Stock Splits'])

final_msft
# Out:
#             Date        Open        High         Low       Close    Volume  \
# 0     2015-01-02   41.259780   41.931820   41.153670   41.348206  27913900
# 1     2015-01-05   41.003344   41.321679   40.897233   40.967976  39673900
# 2     2015-01-06   41.012201   41.339378   40.269418   40.366688  36447900
# 3     2015-01-07   40.658473   41.082920   40.225186   40.879539  29114100
# 4     2015-01-08   41.339360   42.223624   41.312833   42.082142  29645200
# ...          ...         ...         ...         ...         ...       ...
# 1252  2019-12-23  155.743357  155.743357  154.906142  155.044037  17718200
# 1253  2019-12-24  155.112938  155.339492  154.758348  155.014450   8989200
# 1254  2019-12-26  155.191748  156.344160  155.034150  156.285065  14520600
# 1255  2019-12-27  157.053335  157.151837  155.841827  156.570709  18412800
# 1256  2019-12-30  156.600280  156.629827  154.374239  155.221313  16348400
#
#       tweet_count  price_action Ticker  Percent_Change
# ...

# %%
x_labels =["MSFT"]
fig, ax = plt.subplots()
ax.boxplot(final_msft["Percent_Change"], labels=x_labels)
ax.set_title('Distribution of Daily Percent Change in Price')
ax.grid()
plt.show()

# %%
final_msft.to_csv('final_msft.csv', index=False)

# %% [markdown]
# # tesla

# %%
df_tsla_f = df_tsla.reset_index()


df_tsla_f["Date"] = pd.to_datetime(df_tsla_f["Date"], unit='s').dt.strftime('%Y-%m-%d')

final_tsla = pd.merge(df_tsla_f, tsla_df, on='Date')

final_tsla['price_action'] = final_tsla['Close'] - final_tsla['Open']
final_tsla["Ticker"] = "TSLA"
final_tsla['Percent_Change'] = ((final_tsla["Close"]-final_tsla["Open"])/final_tsla["Open"])*100

final_tsla = final_tsla.drop(columns=['Dividends','Stock Splits'])

final_tsla
# Out:
#             Date       Open       High        Low      Close    Volume  \
# 0     2015-01-02  44.574001  44.650002  42.652000  43.862000  23822000
# 1     2015-01-05  42.910000  43.299999  41.431999  42.018002  26842500
# 2     2015-01-06  42.012001  42.840000  40.841999  42.256001  31309500
# 3     2015-01-07  42.669998  42.956001  41.956001  42.189999  14842000
# 4     2015-01-08  42.562000  42.759998  42.001999  42.124001  17212500
# ...          ...        ...        ...        ...        ...       ...
# 1252  2019-12-23  82.356003  84.402000  82.000000  83.844002  66598000
# 1253  2019-12-24  83.671997  85.094002  82.538002  85.050003  40273500
# 1254  2019-12-26  85.582001  86.695999  85.269997  86.188004  53169500
# 1255  2019-12-27  87.000000  87.061996  85.222000  86.075996  49728500
# 1256  2019-12-30  85.758003  85.800003  81.851997  82.940002  62932000
#
#       tweet_count  price_action Ticker  Percent_Change
# 0             200     -0.712002   TSLA       -1.597348
# ...

# %%
x_labels =["TSLA"]
fig, ax = plt.subplots()
ax.boxplot(final_tsla["Percent_Change"], labels=x_labels)
ax.set_title('Distribution of Daily Percent Change in Price')
ax.grid()
plt.show()

# %%
final_tsla.to_csv('final_tsla.csv', index=False)

# %% [markdown]
# # concatenating all companies stock data into one for vizs

# %%
#possible join for the database portion of our assignment***
frames = [final_goog,final_apple,final_msft,final_amzn,final_tsla]
all_comps = pd.concat(frames, axis = 0, join="inner")
all_comps
# Out:
#             Date        Open        High         Low       Close    Volume  \
# 0     2015-01-02  527.561584  529.815369  522.665039  523.373108   1447563
# 1     2015-01-05  521.827332  522.894409  511.655243  512.463013   2059840
# 2     2015-01-06  513.589966  514.761719  499.678131  500.585632   2899940
# 3     2015-01-07  505.611847  505.855164  498.281952  499.727997   2065054
# 4     2015-01-08  496.626526  502.101471  489.655640  501.303680   3353582
# ...          ...         ...         ...         ...         ...       ...
# 1252  2019-12-23   82.356003   84.402000   82.000000   83.844002  66598000
# 1253  2019-12-24   83.671997   85.094002   82.538002   85.050003  40273500
# 1254  2019-12-26   85.582001   86.695999   85.269997   86.188004  53169500
# 1255  2019-12-27   87.000000   87.061996   85.222000   86.075996  49728500
# 1256  2019-12-30   85.758003   85.800003   81.851997   82.940002  62932000
#
#       tweet_count  price_action Ticker  Percent_Change
# ...

# %%
#Send to CSV 
all_comps.to_csv("All_Companies.csv", index=False)
