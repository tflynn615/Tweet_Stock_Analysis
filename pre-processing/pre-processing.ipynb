# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import pandas as pd
import datetime
import yfinance
import mplfinance as mpf
import matplotlib.dates as mpl_dates 
import matplotlib.pyplot as plt 

# google colab specific code
#from google.colab import drive 
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#pip install yfinance

# %%
#pip install mplfinance

# %% [markdown]
# ## Load data

# %%
tweet_id = pd.read_csv('/content/drive/MyDrive/class_/week_20/Company_Tweet.csv')

# %%
tweet_id.head()
# Out:
#              tweet_id ticker_symbol
# 0  550803612197457920          AAPL
# 1  550803610825928706          AAPL
# 2  550803225113157632          AAPL
# 3  550802957370159104          AAPL
# 4  550802855129382912          AAPL

# %%
comp_name = pd.read_csv("/content/drive/MyDrive/class_/week_20/Company.csv")
#comp_name.head()

# %%
tweet_df = pd.read_csv('/content/drive/MyDrive/class_/week_20/Tweet.csv')
tweet_df.head()
# Out:
#              tweet_id           writer  ...  retweet_num like_num
# 0  550441509175443456  VisualStockRSRC  ...            0        1
# 1  550441672312512512      KeralaGuy77  ...            0        0
# 2  550441732014223360      DozenStocks  ...            0        0
# 3  550442977802207232     ShowDreamCar  ...            0        1
# 4  550443807834402816     i_Know_First  ...            0        1
#
# [5 rows x 7 columns]

# %%
name = 'aapl'
ticker = yfinance.Ticker(name)
df_aapl = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')

df_aapl.head()
# Out:
#                  Open       High        Low  ...     Volume  Dividends  Stock Splits
# Date                                         ...
# 2015-01-02  25.286885  25.298236  24.369756  ...  212818400        0.0             0
# 2015-01-05  24.583150  24.664874  23.929355  ...  257142000        0.0             0
# 2015-01-06  24.185883  24.387924  23.752289  ...  263188400        0.0             0
# 2015-01-07  24.335706  24.562718  24.222200  ...  160423600        0.0             0
# 2015-01-08  24.796547  25.459422  24.676229  ...  237458000        0.0             0
#
# [5 rows x 7 columns]

# %%
name = 'amzn'
ticker = yfinance.Ticker(name)
df_amzn = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_amzn.head()
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2015-01-02  312.579987  314.750000  ...          0             0
# 2015-01-05  307.010010  308.380005  ...          0             0
# 2015-01-06  302.239990  303.000000  ...          0             0
# 2015-01-07  297.500000  301.279999  ...          0             0
# 2015-01-08  300.320007  303.140015  ...          0             0
#
# [5 rows x 7 columns]

# %%
name = 'goog'
ticker = yfinance.Ticker(name)
df_goog = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_goog.head()
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2015-01-02  527.561584  529.815369  ...          0           0.0
# 2015-01-05  521.827332  522.894409  ...          0           0.0
# 2015-01-06  513.589966  514.761719  ...          0           0.0
# 2015-01-07  505.611847  505.855164  ...          0           0.0
# 2015-01-08  496.626526  502.101471  ...          0           0.0
#
# [5 rows x 7 columns]

# %%
name = 'msft'
ticker = yfinance.Ticker(name)
df_msft = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_msft.head()
# Out:
#                  Open       High        Low  ...    Volume  Dividends  Stock Splits
# Date                                         ...
# 2015-01-02  41.259780  41.931820  41.153670  ...  27913900        0.0             0
# 2015-01-05  41.003344  41.321679  40.897233  ...  39673900        0.0             0
# 2015-01-06  41.012201  41.339378  40.269418  ...  36447900        0.0             0
# 2015-01-07  40.658473  41.082920  40.225186  ...  29114100        0.0             0
# 2015-01-08  41.339360  42.223624  41.312833  ...  29645200        0.0             0
#
# [5 rows x 7 columns]

# %%
name = 'tsla'
ticker = yfinance.Ticker(name)
df_tsla = ticker.history(interval='1d', start='2015-01-01', end='2019-12-31')
df_tsla.tail()
# Out:
#                  Open       High        Low  ...    Volume  Dividends  Stock Splits
# Date                                         ...
# 2019-12-23  82.356003  84.402000  82.000000  ...  66598000          0             0
# 2019-12-24  83.671997  85.094002  82.538002  ...  40273500          0             0
# 2019-12-26  85.582001  86.695999  85.269997  ...  53169500          0             0
# 2019-12-27  87.000000  87.061996  85.222000  ...  49728500          0             0
# 2019-12-30  85.758003  85.800003  81.851997  ...  62932000          0             0
#
# [5 rows x 7 columns]

# %%
df_tsla.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends         int64
# Stock Splits      int64
# dtype: object

# %%
df_tsla['Date'] = pd.to_datetime(df_tsla.index)
df_tsla['Date'] = df_tsla['Date'].apply(mpl_dates.date2num)

df_tsla = df_tsla.loc[:,['Date', 'Open', 'Close', 'High', 'Low', 'Volume']]
#df_tsla
mpf.plot(df_tsla, type='candle', mav=(21,50), figsize=(10,6), style='mike', volume=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/mplfinance/_arg_validators.py:45: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   category=UserWarning)

# %% [markdown]
# ## Transformation

# %%
#merging company tweet, and tweet dfs on "tweet_id"
merged_df = pd.merge(tweet_id, tweet_df, on="tweet_id")
merged_df.head()
# Out:
#              tweet_id ticker_symbol  ... retweet_num  like_num
# 0  550803612197457920          AAPL  ...           0         1
# 1  550803612197457920          AMZN  ...           0         1
# 2  550803610825928706          AAPL  ...           0         1
# 3  550803610825928706         GOOGL  ...           0         1
# 4  550803610825928706          AMZN  ...           0         1
#
# [5 rows x 8 columns]

# %%
merged_df.ticker_symbol.unique()
# Out:
# array(['AAPL', 'AMZN', 'GOOGL', 'TSLA', 'GOOG', 'MSFT'], dtype=object)

# %%
# Since we have 2 google, removing all the googl ticker 
merged_df = merged_df[merged_df.ticker_symbol !="GOOGL"]

# %%
merged_df.ticker_symbol.unique()
# Out:
# array(['AAPL', 'AMZN', 'TSLA', 'GOOG', 'MSFT'], dtype=object)

# %%
#converting unix epoch to date format similar
merged_df["post_date"] = pd.to_datetime(merged_df["post_date"], unit='s').dt.strftime('%d-%m-%Y')
merged_df.tail()
# Out:
#                     tweet_id ticker_symbol  ... retweet_num like_num
# 4336440  1212158772015034369          TSLA  ...           0        0
# 4336441  1212159099632267268          TSLA  ...           0        0
# 4336442  1212159184931717120          TSLA  ...           1        0
# 4336443  1212159838882533376          TSLA  ...           0        1
# 4336444  1212160015332728833          TSLA  ...           0        5
#
# [5 rows x 8 columns]

# %%
#checking values before dropping null values
merged_df.count()
# Out:
# tweet_id         4008876
# ticker_symbol    4008876
# writer           3955885
# post_date        4008876
# body             4008876
# comment_num      4008876
# retweet_num      4008876
# like_num         4008876
# dtype: int64

# %%
#dropping null values
merged_df = merged_df.dropna()

# %%
#checking values/count after dropping null values
merged_df.count()
# Out:
# tweet_id         3955885
# ticker_symbol    3955885
# writer           3955885
# post_date        3955885
# body             3955885
# comment_num      3955885
# retweet_num      3955885
# like_num         3955885
# dtype: int64

# %%
# Checking start and end date of the tweet data 
merged_df = merged_df.sort_values(by='post_date')
merged_df.head()
# Out:
#                    tweet_id ticker_symbol  ... retweet_num like_num
# 0        550803612197457920          AAPL  ...           0        1
# 2541300  550458273850470401          AMZN  ...           0        0
# 2541301  550458700402413569          AMZN  ...           0        0
# 2541302  550460180631011328          AMZN  ...           0        0
# 2541303  550460947098505216          AMZN  ...           1        1
#
# [5 rows x 8 columns]

# %%
merged_df.tail()
# Out:
#                     tweet_id ticker_symbol  ... retweet_num like_num
# 1863763  1212105085481734144          AAPL  ...           0        0
# 1863762  1212104890828443652          AAPL  ...           0        7
# 1863761  1212104837023842304          AAPL  ...           0        6
# 1863768  1212105694704472066          MSFT  ...           0        0
# 4336444  1212160015332728833          TSLA  ...           0        5
#
# [5 rows x 8 columns]

# %%
# Double check nulls
merged_df.isnull().sum()
# Out:
# tweet_id         0
# ticker_symbol    0
# writer           0
# post_date        0
# body             0
# comment_num      0
# retweet_num      0
# like_num         0
# dtype: int64

# %%
# remane post_date 
merged_df = merged_df.rename(columns={'post_date': 'Date'}, errors='raise')
merged_df.head()
# Out:
#                    tweet_id ticker_symbol  ... retweet_num like_num
# 0        550803612197457920          AAPL  ...           0        1
# 2541300  550458273850470401          AMZN  ...           0        0
# 2541301  550458700402413569          AMZN  ...           0        0
# 2541302  550460180631011328          AMZN  ...           0        0
# 2541303  550460947098505216          AMZN  ...           1        1
#
# [5 rows x 8 columns]

# %%
merged_df = merged_df.drop(columns=['writer', 'body'])
merged_df.head()
# Out:
#                    tweet_id ticker_symbol  ... retweet_num  like_num
# 0        550803612197457920          AAPL  ...           0         1
# 2541300  550458273850470401          AMZN  ...           0         0
# 2541301  550458700402413569          AMZN  ...           0         0
# 2541302  550460180631011328          AMZN  ...           0         0
# 2541303  550460947098505216          AMZN  ...           1         1
#
# [5 rows x 6 columns]

# %% [markdown]
# ##tweet activity df for each tickers

# %% [markdown]
# Apple

# %%
# columns
cols = ["Date","tweet_count"]

# %%
AAPL = merged_df[(merged_df['ticker_symbol']=="AAPL")]
AAPL
# Out:
#                     tweet_id ticker_symbol  ... retweet_num  like_num
# 0         550803612197457920          AAPL  ...           0         1
# 370       550447574285418497          AAPL  ...           0         0
# 371       550445850170642432          AAPL  ...           0         2
# 372       550445066444369921          AAPL  ...           0         0
# 373       550444970738335744          AAPL  ...           0         0
# ...                      ...           ...  ...         ...       ...
# 1863765  1212105191425658880          AAPL  ...           0         2
# 1863764  1212105111637569536          AAPL  ...           0         0
# 1863763  1212105085481734144          AAPL  ...           0         0
# 1863762  1212104890828443652          AAPL  ...           0         7
# 1863761  1212104837023842304          AAPL  ...           0         6
#
# [1414802 rows x 6 columns]

# %%
#creading df of tweets per day to merge with stock dfs
aapl_df = pd.DataFrame(AAPL.Date.value_counts()).reset_index()
#setting the appropriate columns
aapl_df.columns=cols

aapl_df
# Out:
#             Date  tweet_count
# 0     07-09-2016         5018
# 1     03-01-2019         4914
# 2     09-03-2015         4615
# 3     09-09-2016         4509
# 4     27-04-2015         4453
# ...          ...          ...
# 1814  28-03-2017           27
# 1815  03-10-2018           14
# 1816  13-03-2017           12
# 1817  02-05-2015           10
# 1818  08-09-2017            7
#
# [1819 rows x 2 columns]

# %% [markdown]
# Amazon

# %%
AMZN = merged_df[(merged_df["ticker_symbol"]=="AMZN")]

amzn_df = pd.DataFrame(AMZN.Date.value_counts()).reset_index()
amzn_df.columns=cols

amzn_df
# Out:
#             Date  tweet_count
# 0     16-06-2017         4167
# 1     23-07-2015         2385
# 2     28-01-2016         2231
# 3     24-07-2015         2197
# 4     26-07-2018         2159
# ...          ...          ...
# 1821  21-09-2018           20
# 1822  28-03-2015           16
# 1823  18-10-2017           12
# 1824  30-05-2017           11
# 1825  03-05-2015           10
#
# [1826 rows x 2 columns]

# %% [markdown]
# Google

# %%
GOOG = merged_df[(merged_df["ticker_symbol"]=="GOOG")]

goog_df = pd.DataFrame(GOOG.Date.value_counts()).reset_index()
goog_df.columns=cols

goog_df
# Out:
#             Date  tweet_count
# 0     05-10-2016         1518
# 1     19-05-2016         1477
# 2     04-10-2016         1446
# 3     17-07-2015         1220
# 4     18-05-2016         1050
# ...          ...          ...
# 1820  16-09-2018           23
# 1821  12-01-2019           22
# 1822  08-01-2016           22
# 1823  18-08-2016           14
# 1824  26-05-2019            9
#
# [1825 rows x 2 columns]

# %% [markdown]
# Microsoft

# %%
MSFT = merged_df[(merged_df["ticker_symbol"]=="MSFT")]

msft_df = pd.DataFrame(MSFT.Date.value_counts()).reset_index()
msft_df.columns=cols

msft_df
# Out:
#             Date  tweet_count
# 0     13-06-2016         2884
# 1     14-06-2016         1755
# 2     27-01-2015         1168
# 3     22-04-2016         1002
# 4     20-10-2016          964
# ...          ...          ...
# 1821  29-08-2015           27
# 1822  02-04-2016           25
# 1823  02-05-2015           25
# 1824  03-05-2015           11
# 1825  18-06-2019            9
#
# [1826 rows x 2 columns]

# %% [markdown]
# Tesla

# %%
TSLA = merged_df[(merged_df["ticker_symbol"]=="TSLA")]

tsla_df = pd.DataFrame(TSLA.Date.value_counts()).reset_index()
tsla_df.columns=cols

tsla_df
# Out:
#             Date  tweet_count
# 0     07-08-2018         6329
# 1     08-08-2018         4542
# 2     28-09-2018         4387
# 3     04-04-2019         3852
# 4     01-08-2018         3644
# ...          ...          ...
# 1821  06-03-2018           31
# 1822  08-12-2015           28
# 1823  03-05-2015           26
# 1824  15-01-2017           24
# 1825  08-01-2016           19
#
# [1826 rows x 2 columns]

# %% [markdown]
# merging tweet activity to original

# %%
aapl_merged = pd.merge(AAPL, aapl_df, on='Date')
aapl_merged.head()
# Out:
#              tweet_id ticker_symbol  ... like_num  tweet_count
# 0  550803612197457920          AAPL  ...        1          298
# 1  550447574285418497          AAPL  ...        0          298
# 2  550445850170642432          AAPL  ...        2          298
# 3  550445066444369921          AAPL  ...        0          298
# 4  550444970738335744          AAPL  ...        0          298
#
# [5 rows x 7 columns]

# %%
amzn_merged = pd.merge(AMZN, amzn_df, on='Date')
amzn_merged.head()
# Out:
#              tweet_id ticker_symbol  ... like_num  tweet_count
# 0  550458273850470401          AMZN  ...        0          130
# 1  550458700402413569          AMZN  ...        0          130
# 2  550460180631011328          AMZN  ...        0          130
# 3  550460947098505216          AMZN  ...        1          130
# 4  550463153499561984          AMZN  ...        0          130
#
# [5 rows x 7 columns]

# %%
goog_merged = pd.merge(GOOG, goog_df, on='Date')
goog_merged.head()
# Out:
#              tweet_id ticker_symbol  ... like_num  tweet_count
# 0  550709117439197185          GOOG  ...        0           60
# 1  550715741012754432          GOOG  ...        0           60
# 2  550718889362202625          GOOG  ...        0           60
# 3  550722604357922816          GOOG  ...        1           60
# 4  550723007849967616          GOOG  ...        0           60
#
# [5 rows x 7 columns]

# %%
msft_merged = pd.merge(MSFT, msft_df, on='Date')
msft_merged.head()
# Out:
#              tweet_id ticker_symbol  ... like_num  tweet_count
# 0  550724623583948800          MSFT  ...        1           53
# 1  550444112328261632          MSFT  ...        0           53
# 2  550455384734183424          MSFT  ...        0           53
# 3  550721449804054529          MSFT  ...        1           53
# 4  550466945061908482          MSFT  ...        0           53
#
# [5 rows x 7 columns]

# %%
tsla_merged = pd.merge(TSLA, tsla_df, on='Date')
tsla_merged.head()
# Out:
#              tweet_id ticker_symbol  ... like_num  tweet_count
# 0  550508554642550784          TSLA  ...        0           99
# 1  550447850857828352          TSLA  ...        2           99
# 2  550443858010861568          TSLA  ...        1           99
# 3  550443857692078081          TSLA  ...        1           99
# 4  550443857595600896          TSLA  ...        1           99
#
# [5 rows x 7 columns]

# %% [markdown]
# ## final merge

# %% [markdown]
# Apple

# %%
df_aapl_f = df_aapl
df_aapl_f
# Out:
#                  Open       High        Low  ...     Volume  Dividends  Stock Splits
# Date                                         ...
# 2015-01-02  25.286885  25.298236  24.369756  ...  212818400        0.0             0
# 2015-01-05  24.583150  24.664874  23.929355  ...  257142000        0.0             0
# 2015-01-06  24.185883  24.387924  23.752289  ...  263188400        0.0             0
# 2015-01-07  24.335706  24.562718  24.222200  ...  160423600        0.0             0
# 2015-01-08  24.796547  25.459422  24.676229  ...  237458000        0.0             0
# ...               ...        ...        ...  ...        ...        ...           ...
# 2019-12-23  69.310552  70.229652  69.271019  ...   98572000        0.0             0
# 2019-12-24  70.338354  70.387771  69.901043  ...   48478800        0.0             0
# 2019-12-26  70.370482  71.645364  70.340834  ...   93121200        0.0             0
# 2019-12-27  71.927010  72.631161  71.185800  ...  146266000        0.0             0
# 2019-12-30  71.516870  72.314908  70.469295  ...  144114400        0.0             0
#
# [1257 rows x 7 columns]

# %%
df_aapl_f['Date'] = pd.to_datetime(df_aapl_f.index)
df_aapl_f["Date"] = pd.to_datetime(df_aapl_f["Date"], unit='s').dt.strftime('%d-%m-%Y')

df_aapl_f.reset_index(drop=True, inplace=True)
df_aapl_f
# Out:
#            Open       High        Low  ...  Dividends  Stock Splits        Date
# 0     25.286885  25.298236  24.369756  ...        0.0             0  02-01-2015
# 1     24.583150  24.664874  23.929355  ...        0.0             0  05-01-2015
# 2     24.185883  24.387924  23.752289  ...        0.0             0  06-01-2015
# 3     24.335706  24.562718  24.222200  ...        0.0             0  07-01-2015
# 4     24.796547  25.459422  24.676229  ...        0.0             0  08-01-2015
# ...         ...        ...        ...  ...        ...           ...         ...
# 1252  69.310552  70.229652  69.271019  ...        0.0             0  23-12-2019
# 1253  70.338354  70.387771  69.901043  ...        0.0             0  24-12-2019
# 1254  70.370482  71.645364  70.340834  ...        0.0             0  26-12-2019
# 1255  71.927010  72.631161  71.185800  ...        0.0             0  27-12-2019
# 1256  71.516870  72.314908  70.469295  ...        0.0             0  30-12-2019
#
# [1257 rows x 8 columns]

# %%
final_apple = pd.merge(df_aapl_f, aapl_df, on='Date')
final_apple.head()
# Out:
#         Open       High        Low  ...  Stock Splits        Date  tweet_count
# 0  25.286885  25.298236  24.369756  ...             0  02-01-2015          864
# 1  24.583150  24.664874  23.929355  ...             0  05-01-2015         1145
# 2  24.185883  24.387924  23.752289  ...             0  06-01-2015         1184
# 3  24.335706  24.562718  24.222200  ...             0  07-01-2015         1079
# 4  24.796547  25.459422  24.676229  ...             0  08-01-2015         1465
#
# [5 rows x 9 columns]

# %%
final_apple['price_action'] = final_apple['Close'] - final_apple['Open']

final_apple.tail()
# Out:
#            Open       High        Low  ...        Date  tweet_count  price_action
# 1249  69.310552  70.229652  69.271019  ...  23-12-2019          595      0.857333
# 1250  70.338354  70.387771  69.901043  ...  24-12-2019          349     -0.103773
# 1251  70.370482  71.645364  70.340834  ...  26-12-2019          686      1.257585
# 1252  71.927010  72.631161  71.185800  ...  27-12-2019          380     -0.326134
# 1253  71.516870  72.314908  70.469295  ...  30-12-2019          724      0.508964
#
# [5 rows x 10 columns]

# %%
final_apple = final_apple.drop(columns=['Open','Close','High','Low','Dividends','Stock Splits'])
final_apple
# Out:
#          Volume        Date  tweet_count  price_action
# 0     212818400  02-01-2015          864     -0.467645
# 1     257142000  05-01-2015         1145     -0.463105
# 2     263188400  06-01-2015         1184     -0.063563
# 3     160423600  07-01-2015         1079      0.124857
# 4     237458000  08-01-2015         1465      0.603852
# ...         ...         ...          ...           ...
# 1249   98572000  23-12-2019          595      0.857333
# 1250   48478800  24-12-2019          349     -0.103773
# 1251   93121200  26-12-2019          686      1.257585
# 1252  146266000  27-12-2019          380     -0.326134
# 1253  144114400  30-12-2019          724      0.508964
#
# [1254 rows x 4 columns]

# %%
#final_apple.to_csv('/content/drive/MyDrive/class_/week_20/final_aapl.csv', index=False)

# %%
x_axis = final_apple['Date']
y_axis = final_apple['tweet_count']
plt.plot(x_axis, y_axis, label='Apple')
plt.title("Apple tweet volume")
plt.legend()
#plt.rcParams["figure.figsize"] = (10,4)

# plt.savefig("add a path and figure extension")

# %%
x_axis = final_apple['Date']
y_axis = final_apple['price_action']
plt.plot(x_axis, y_axis, label='Apple')
plt.title("Apple Price action")
plt.legend()

# %% [markdown]
# Amazon

# %%
df_amzn_f = df_amzn
df_amzn_f

df_amzn_f['Date'] = pd.to_datetime(df_amzn_f.index)
df_amzn_f["Date"] = pd.to_datetime(df_amzn_f["Date"], unit='s').dt.strftime('%d-%m-%Y')

df_amzn_f.reset_index(drop=True, inplace=True)

final_amzn = pd.merge(df_amzn_f, amzn_df, on='Date')

final_amzn['price_action'] = final_amzn['Close'] - final_amzn['Open']
final_amzn = final_amzn.drop(columns=['Open','Close','High','Low','Dividends','Stock Splits'])

# %%
final_amzn
# Out:
#        Volume        Date  tweet_count  price_action
# 0     2783200  02-01-2015          174     -4.059998
# 1     2774200  05-01-2015          279     -4.820007
# 2     3519000  06-01-2015          202     -6.949982
# 3     2640300  07-01-2015          193      0.920013
# 4     3088400  08-01-2015          215      0.139984
# ...       ...         ...          ...           ...
# 1252  2136400  23-12-2019          265      4.739990
# 1253   881300  24-12-2019          237     -4.600098
# 1254  6005400  26-12-2019         1289     67.760010
# 1255  6186600  27-12-2019          945    -13.119995
# 1256  3674700  30-12-2019          520    -27.109985
#
# [1257 rows x 4 columns]

# %%
#final_amzn.to_csv('/content/drive/MyDrive/class_/week_20/final_amzn.csv', index=False)

# %% [markdown]
# google

# %%
df_goog_f = df_goog
df_goog_f

df_goog_f['Date'] = pd.to_datetime(df_goog_f.index)
df_goog_f["Date"] = pd.to_datetime(df_goog_f["Date"], unit='s').dt.strftime('%d-%m-%Y')

df_goog_f.reset_index(drop=True, inplace=True)

final_goog = pd.merge(df_goog_f, goog_df, on='Date')

final_goog['price_action'] = final_goog['Close'] - final_goog['Open']
final_goog = final_goog.drop(columns=['Open','Close','High','Low','Dividends','Stock Splits'])

final_goog
# Out:
#        Volume        Date  tweet_count  price_action
# 0     1447563  02-01-2015          145     -4.188477
# 1     2059840  05-01-2015          298     -9.364319
# 2     2899940  06-01-2015          358    -13.004333
# 3     2065054  07-01-2015          357     -5.883850
# 4     3353582  08-01-2015          503      4.677155
# ...       ...         ...          ...           ...
# 1251   883100  23-12-2019           86     -7.030029
# 1252   347500  24-12-2019          115     -4.939941
# 1253   667500  26-12-2019          144     14.229980
# 1254  1038400  27-12-2019           91    -11.099976
# 1255  1050900  30-12-2019          160    -13.859985
#
# [1256 rows x 4 columns]

# %%
#final_goog.to_csv('/content/drive/MyDrive/class_/week_20/final_goog.csv', index=False)

# %% [markdown]
# microsoft

# %%
df_msft_f = df_msft
df_msft_f

df_msft_f['Date'] = pd.to_datetime(df_msft_f.index)
df_msft_f["Date"] = pd.to_datetime(df_msft_f["Date"], unit='s').dt.strftime('%d-%m-%Y')

df_msft_f.reset_index(drop=True, inplace=True)

final_msft = pd.merge(df_msft_f, msft_df, on='Date')

final_msft['price_action'] = final_msft['Close'] - final_msft['Open']
final_msft = final_msft.drop(columns=['Open','Close','High','Low','Dividends','Stock Splits'])

final_msft
# Out:
#         Volume        Date  tweet_count  price_action
# 0     27913900  02-01-2015          107      0.088425
# 1     39673900  05-01-2015          112     -0.035368
# 2     36447900  06-01-2015           78     -0.645513
# 3     29114100  07-01-2015           88      0.221066
# 4     29645200  08-01-2015          134      0.742782
# ...        ...         ...          ...           ...
# 1252  17718200  23-12-2019          149     -0.699320
# 1253   8989200  24-12-2019          125     -0.098488
# 1254  14520600  26-12-2019          186      1.093316
# 1255  18412800  27-12-2019          208     -0.482625
# 1256  16348400  30-12-2019          244     -1.378966
#
# [1257 rows x 4 columns]

# %%
#final_msft.to_csv('/content/drive/MyDrive/class_/week_20/final_msft.csv', index=False)

# %% [markdown]
# tesla

# %%
df_tsla_f = df_tsla
df_tsla_f

df_tsla_f['Date'] = pd.to_datetime(df_tsla_f.index)
df_tsla_f["Date"] = pd.to_datetime(df_tsla_f["Date"], unit='s').dt.strftime('%d-%m-%Y')

df_tsla_f.reset_index(drop=True, inplace=True)

final_tsla = pd.merge(df_tsla_f, tsla_df, on='Date')

final_tsla['price_action'] = final_tsla['Close'] - final_tsla['Open']
final_tsla = final_tsla.drop(columns=['Open','Close','High','Low','Dividends','Stock Splits'])

final_tsla
# Out:
#         Volume        Date  tweet_count  price_action
# 0     23822000  02-01-2015          200     -0.712002
# 1     26842500  05-01-2015          277     -0.891998
# 2     31309500  06-01-2015          237      0.243999
# 3     14842000  07-01-2015          245     -0.480000
# 4     17212500  08-01-2015          231     -0.438000
# ...        ...         ...          ...           ...
# 1252  66598000  23-12-2019         2513      1.487999
# 1253  40273500  24-12-2019         1249      1.378006
# 1254  53169500  26-12-2019         1175      0.606003
# 1255  49728500  27-12-2019         1274     -0.924004
# 1256  62932000  30-12-2019         1383     -2.818001
#
# [1257 rows x 4 columns]

# %%
#final_tsla.to_csv('/content/drive/MyDrive/class_/week_20/final_tsla.csv', index=False)
