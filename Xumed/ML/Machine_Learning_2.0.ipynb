# %%
import boto3
# Out:
# Mounted at /content/drive

# %%
#!pip install s3fs

# %%
#!pip install boto3

# %%
# imports 
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## APPLE

# %%
aapl_df = pd.read_csv('s3://stock-csvs/final_aapl.csv')
aapl_df.head()
# Out:
#       Volume        Date  tweet_count  price_action
# 0  212818400  02-01-2015          864     -0.467645
# 1  257142000  05-01-2015         1145     -0.463105
# 2  263188400  06-01-2015         1184     -0.063563
# 3  160423600  07-01-2015         1079      0.124857
# 4  237458000  08-01-2015         1465      0.603852

# %%
aapl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Volume        1254 non-null   int64
#  1   Date          1254 non-null   object
#  2   tweet_count   1254 non-null   int64
#  3   price_action  1254 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
aapl_df.isnull().sum()
# Out:
# Volume          0
# Date            0
# tweet_count     0
# price_action    0
# dtype: int64

# %%
# drop nulls
aapl_df = aapl_df.dropna()

# %%
aapl_df.isnull().sum()
# Out:
# Volume          0
# Date            0
# tweet_count     0
# price_action    0
# dtype: int64

# %%
# drop date?
#aapl_df = aapl_df.drop(columns=['Date'], inplace=True)
#aapl_df.head()

# %%
# convert to datetime
aapl_df['Date'] = pd.to_datetime(aapl_df['Date'])

# %%
aapl_df.dtypes
# Out:
# Volume                   int64
# Date            datetime64[ns]
# tweet_count              int64
# price_action           float64
# dtype: object

# %%
# APPLE's histogram
col = aapl_df[['tweet_count', 'price_action', 'Volume']]
for i in col.columns:
  plt.hist(col[i])
  plt.title(i)
  plt.show()

# %%
import seaborn as sns 

print(col.corr())
sns.heatmap(col.corr())
# Out:
#               tweet_count  price_action    Volume
# tweet_count      1.000000     -0.033593  0.626765
# price_action    -0.033593      1.000000 -0.118457
# Volume           0.626765     -0.118457  1.000000

# %%
# Realtionship between tweet count and price action

plt.scatter(aapl_df.tweet_count, aapl_df.price_action)
plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()

# %%
X = aapl_df.tweet_count.values.reshape(-1,1)

# %%
X.shape
# Out:
# (1254, 1)

# %%
y = aapl_df.price_action

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1254,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()

# %%
# Realtionship between tweet count and Volume

plt.scatter(aapl_df.tweet_count, aapl_df.Volume)
plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()

# %%
y = aapl_df.Volume

model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1254,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ## Amazon

# %%
# load 
amzn_df = pd.read_csv('s3://stock-csvs/final_amzn.csv')
amzn_df.head()
# Out:
#     Volume        Date  tweet_count  price_action
# 0  2783200  02-01-2015          174     -4.059998
# 1  2774200  05-01-2015          279     -4.820007
# 2  3519000  06-01-2015          202     -6.949982
# 3  2640300  07-01-2015          193      0.920013
# 4  3088400  08-01-2015          215      0.139984

# %%
# drop nulls
amzn_df = amzn_df.dropna()

# %%
amzn_df.isnull().sum()
# Out:
# Volume          0
# Date            0
# tweet_count     0
# price_action    0
# dtype: int64

# %%
# AMazons's histogram
am_col = amzn_df[['tweet_count', 'price_action', 'Volume']]
for i in am_col.columns:
  plt.hist(am_col[i])
  plt.title(i)
  plt.show()

# %%
import seaborn as sns 

print(am_col.corr())
sns.heatmap(am_col.corr())
# Out:
#               tweet_count  price_action    Volume
# tweet_count      1.000000      0.018293  0.582459
# price_action     0.018293      1.000000 -0.107615
# Volume           0.582459     -0.107615  1.000000

# %%
# Realtionship between tweet count and price action

plt.scatter(amzn_df.tweet_count, amzn_df.price_action)
plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()

# %%
# tweet vs price action, Amzn
X = amzn_df.tweet_count.values.reshape(-1,1)
y = amzn_df.price_action
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()
# Out:
# (1257,)

# %%
# tweet vs Volume, Amzn
plt.scatter(amzn_df.tweet_count, amzn_df.Volume)
plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()

# %%
y = amzn_df.Volume

model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1257,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ## Google

# %%
# load 
goog_df = pd.read_csv('s3://stock-csvs/final_goog.csv')
goog_df.head()
# Out:
#     Volume        Date  tweet_count  price_action
# 0  1447563  02-01-2015          145     -4.188477
# 1  2059840  05-01-2015          298     -9.364319
# 2  2899940  06-01-2015          358    -13.004333
# 3  2065054  07-01-2015          357     -5.883850
# 4  3353582  08-01-2015          503      4.677155

# %%
# drop nulls
goog_df = goog_df.dropna()
goog_df.isnull().sum()
# Out:
# Volume          0
# Date            0
# tweet_count     0
# price_action    0
# dtype: int64

# %%
# Google's histogram
g_col = goog_df[['tweet_count', 'price_action', 'Volume']]
for i in g_col.columns:
  plt.hist(g_col[i])
  plt.title(i)
  plt.show()

# %%
import seaborn as sns 

print(g_col.corr())
sns.heatmap(g_col.corr())
# Out:
#               tweet_count  price_action    Volume
# tweet_count      1.000000     -0.000151  0.362551
# price_action    -0.000151      1.000000 -0.112349
# Volume           0.362551     -0.112349  1.000000

# %%
# Realtionship between tweet count and price action

plt.scatter(goog_df.tweet_count, goog_df.price_action)
plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()

# %%
# tweet vs price action, google
X = goog_df.tweet_count.values.reshape(-1,1)
y = goog_df.price_action
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()
# Out:
# (1256,)

# %%
# tweet vs Volume, google
plt.scatter(goog_df.tweet_count, goog_df.Volume)
plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()

# %%
y = goog_df.Volume

model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()
# Out:
# (1256,)

# %% [markdown]
# ## Microsoft

# %%
# load 
msft_df = pd.read_csv('s3://stock-csvs/final_msft.csv')
msft_df.head()
# Out:
#      Volume        Date  tweet_count  price_action
# 0  27913900  02-01-2015          107      0.088425
# 1  39673900  05-01-2015          112     -0.035368
# 2  36447900  06-01-2015           78     -0.645513
# 3  29114100  07-01-2015           88      0.221066
# 4  29645200  08-01-2015          134      0.742782

# %%
# drop nulls
msft_df = msft_df.dropna()
msft_df.isnull().sum()

# MS's histogram
m_col = msft_df[['tweet_count', 'price_action', 'Volume']]
for i in m_col.columns:
  plt.hist(m_col[i])
  plt.title(i)
  plt.show()

# %%
import seaborn as sns 

print(m_col.corr())
sns.heatmap(m_col.corr())
# Out:
#               tweet_count  price_action    Volume
# tweet_count      1.000000     -0.004039  0.309094
# price_action    -0.004039      1.000000 -0.109855
# Volume           0.309094     -0.109855  1.000000

# %%
# Realtionship between tweet count and price action

plt.scatter(msft_df.tweet_count, msft_df.price_action)
plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()

# %%
# tweet vs price action, MS
X = msft_df.tweet_count.values.reshape(-1,1)
y = msft_df.price_action
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()
# Out:
# (1257,)

# %%
# tweet vs Volume, MS
plt.scatter(msft_df.tweet_count, msft_df.Volume)
plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()

# %%
y = msft_df.Volume

model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()
# Out:
# (1257,)

# %% [markdown]
# ## Tesla

# %%
# load 
tsla_df = pd.read_csv('s3://stock-csvs/final_tsla.csv')
tsla_df.head()
# Out:
#      Volume        Date  tweet_count  price_action
# 0  23822000  02-01-2015          200     -0.712002
# 1  26842500  05-01-2015          277     -0.891998
# 2  31309500  06-01-2015          237      0.243999
# 3  14842000  07-01-2015          245     -0.480000
# 4  17212500  08-01-2015          231     -0.438000

# %%
# drop nulls
tsla_df = tsla_df.dropna()
tsla_df.isnull().sum()

# Tesla's histogram
t_col = tsla_df[['tweet_count', 'price_action', 'Volume']]
for i in t_col.columns:
  plt.hist(t_col[i])
  plt.title(i)
  plt.show()

# %%
# Realtionship between tweet count and price action

plt.scatter(tsla_df.tweet_count, tsla_df.price_action)
plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()

# %%
# tweet vs price action, Tesla
X = tsla_df.tweet_count.values.reshape(-1,1)
y = tsla_df.price_action
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('price action')
plt.show()
# Out:
# (1257,)

# %%
# tweet vs Volume, Tesla
plt.scatter(tsla_df.tweet_count, tsla_df.Volume)
plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()

# %%
y = tsla_df.Volume

model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')

plt.xlabel('tweets')
plt.ylabel('Volume')
plt.show()
# Out:
# (1257,)

# %% [markdown]
# ## ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
# Avg tsla daily volume = 25,000,000
tsla_df['liquid_lvl'] = 0

tsla_df.loc[tsla_df['Volume'] >= 25000000, 'liquid_lvl'] = 1 

tsla_df = tsla_df.drop(columns='Date')
tsla_df
# Out:
#         Volume  tweet_count  price_action  liquid_lvl
# 0     23822000          200     -0.712002           0
# 1     26842500          277     -0.891998           1
# 2     31309500          237      0.243999           1
# 3     14842000          245     -0.480000           0
# 4     17212500          231     -0.438000           0
# ...        ...          ...           ...         ...
# 1252  66598000         2513      1.487999           1
# 1253  40273500         1249      1.378006           1
# 1254  53169500         1175      0.606003           1
# 1255  49728500         1274     -0.924004           1
# 1256  62932000         1383     -2.818001           1
#
# [1257 rows x 4 columns]

# %%
y = tsla_df['liquid_lvl']
X = tsla_df.drop(columns='liquid_lvl')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, stratify=y)

X_train.shape
# Out:
# (942, 3)

# %%
classifier = LogisticRegression(solver='lbfgs', max_iter=200, random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = classifier.predict(X_test)
results = pd.DataFrame({'Predictions': y_pred, 'Actual': y_test}).reset_index(drop=True)
results
# Out:
#      Predictions  Actual
# 0              1       1
# 1              1       1
# 2              1       1
# 3              1       1
# 4              1       1
# ..           ...     ...
# 310            1       1
# 311            1       0
# 312            1       0
# 313            1       1
# 314            1       1
#
# [315 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.5746031746031746

# %% [markdown]
# ## tensorflow

# %%
import tensorflow as tf

# %%
# Split our preprocessed data into our features and target arrays
y = tsla_df['liquid_lvl'].values
X = tsla_df.drop(['liquid_lvl'],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=66)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
len(X_train[0])
# Out:
# 3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 6

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 6)                 24
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.8488 - accuracy: 0.3355
# Epoch 2/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.8025 - accuracy: 0.3524
# Epoch 3/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.7623 - accuracy: 0.3992
# Epoch 4/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.7257 - accuracy: 0.5064
# Epoch 5/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6918 - accuracy: 0.5839
# Epoch 6/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6591 - accuracy: 0.6454
# Epoch 7/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6268 - accuracy: 0.7059
# Epoch 8/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5940 - accuracy: 0.7569
# Epoch 9/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5612 - accuracy: 0.8057
# Epoch 10/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.8355
# Epoch 11/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4994 - accuracy: 0.8652
# Epoch 12/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4714 - accuracy: 0.8769
# Epoch 13/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4461 - accuracy: 0.8769
# Epoch 14/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.8832
# Epoch 15/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8832
# Epoch 16/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3830 - accuracy: 0.8854
# Epoch 17/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3657 - accuracy: 0.8896
# Epoch 18/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8907
# Epoch 19/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3350 - accuracy: 0.8928
# Epoch 20/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3213 - accuracy: 0.8960
# Epoch 21/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3085 - accuracy: 0.8981
# Epoch 22/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2964 - accuracy: 0.8992
# Epoch 23/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2852 - accuracy: 0.9034
# Epoch 24/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2748 - accuracy: 0.9055
# Epoch 25/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2656 - accuracy: 0.9066
# Epoch 26/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2574 - accuracy: 0.9108
# Epoch 27/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.9130
# Epoch 28/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2427 - accuracy: 0.9151
# Epoch 29/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2359 - accuracy: 0.9161
# Epoch 30/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2299 - accuracy: 0.9183
# Epoch 31/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2237 - accuracy: 0.9204
# Epoch 32/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2182 - accuracy: 0.9225
# Epoch 33/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2130 - accuracy: 0.9257
# Epoch 34/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.9278
# Epoch 35/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2030 - accuracy: 0.9321
# Epoch 36/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.9363
# Epoch 37/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1941 - accuracy: 0.9384
# Epoch 38/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1897 - accuracy: 0.9427
# Epoch 39/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1858 - accuracy: 0.9437
# Epoch 40/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1816 - accuracy: 0.9448
# Epoch 41/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1778 - accuracy: 0.9469
# Epoch 42/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1740 - accuracy: 0.9469
# Epoch 43/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1704 - accuracy: 0.9480
# Epoch 44/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1668 - accuracy: 0.9501
# Epoch 45/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1635 - accuracy: 0.9512
# Epoch 46/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.9501
# Epoch 47/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1570 - accuracy: 0.9501
# Epoch 48/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1537 - accuracy: 0.9512
# Epoch 49/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1507 - accuracy: 0.9522
# Epoch 50/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1479 - accuracy: 0.9522
# Epoch 51/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1449 - accuracy: 0.9533
# Epoch 52/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1421 - accuracy: 0.9544
# Epoch 53/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1393 - accuracy: 0.9554
# Epoch 54/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1367 - accuracy: 0.9544
# Epoch 55/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1340 - accuracy: 0.9554
# Epoch 56/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1316 - accuracy: 0.9575
# Epoch 57/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1292 - accuracy: 0.9586
# Epoch 58/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1269 - accuracy: 0.9597
# Epoch 59/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1246 - accuracy: 0.9607
# Epoch 60/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9618
# Epoch 61/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.9628
# Epoch 62/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1185 - accuracy: 0.9639
# Epoch 63/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1164 - accuracy: 0.9692
# Epoch 64/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.9692
# Epoch 65/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1127 - accuracy: 0.9692
# Epoch 66/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1109 - accuracy: 0.9703
# Epoch 67/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1092 - accuracy: 0.9713
# Epoch 68/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1076 - accuracy: 0.9713
# Epoch 69/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1059 - accuracy: 0.9713
# Epoch 70/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.9713
# Epoch 71/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.9703
# Epoch 72/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.9724
# Epoch 73/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1001 - accuracy: 0.9745
# Epoch 74/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0988 - accuracy: 0.9745
# Epoch 75/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0974 - accuracy: 0.9735
# Epoch 76/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0961 - accuracy: 0.9745
# Epoch 77/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0949 - accuracy: 0.9777
# Epoch 78/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0938 - accuracy: 0.9745
# Epoch 79/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0927 - accuracy: 0.9766
# Epoch 80/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0916 - accuracy: 0.9766
# Epoch 81/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0902 - accuracy: 0.9766
# Epoch 82/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0892 - accuracy: 0.9766
# Epoch 83/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0883 - accuracy: 0.9798
# Epoch 84/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0871 - accuracy: 0.9798
# Epoch 85/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0861 - accuracy: 0.9798
# Epoch 86/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0853 - accuracy: 0.9809
# Epoch 87/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0844 - accuracy: 0.9809
# Epoch 88/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0834 - accuracy: 0.9798
# Epoch 89/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9809
# Epoch 90/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9820
# Epoch 91/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9830
# Epoch 92/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.9830
# Epoch 93/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0792 - accuracy: 0.9820
# Epoch 94/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0783 - accuracy: 0.9841
# Epoch 95/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9830
# Epoch 96/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0767 - accuracy: 0.9830
# Epoch 97/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0762 - accuracy: 0.9841
# Epoch 98/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0753 - accuracy: 0.9841
# Epoch 99/100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9841
# Epoch 100/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9830
# 10/10 - 0s - loss: 0.0952 - accuracy: 0.9746
# Loss: 0.09517011046409607, Accuracy: 0.9746031761169434

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
